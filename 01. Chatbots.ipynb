# %%
import nltk
import re
from nltk.chat.util import Chat, reflections

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lokenda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Lokenda\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
pairs = [
    # Greetings
    [
        r"hi|hello|hey|g'day|sup|what's up",
        [
            "Hey there! What's on your mind?",
            "Hello! How's your day going so far?",
            "Hi! How can I help you out today?",
            "Hey! Good to see you. What can I do for you?",
        ],
    ],
    # Introductions
    [
        r"my name is (.*)|i am (.*)",
        [
            "Nice to meet you, %1! How can I help you today?",
            "Hey %1! It's great to put a name to the chat. What's up?",
            "Got it, %1. How can I assist you?",
        ],
    ],
    # Asking for the bot's name
    [
        r"(.*) your name\?",
        [
            "I'm just your friendly neighbourhood chatbot!",
            "You can just call me your virtual assistant. What's your name?",
            "I don't really have a human name, but I'm here whenever you need a hand.",
        ],
    ],
    # Small talk: How are you?
    [
        r"how are you\?|how are you doing\?|how's it going\?",
        [
            "I'm doing great, thanks for asking! How are things with you?",
            "Can't complain! Just hanging out in the digital world. How are you doing?",
            "All systems are running smoothly! How's your day going?",
        ],
    ],
    # User feeling down or venting
    [
        r"i'm (sad|stressed|tired|bored|upset)",
        [
            "I'm really sorry to hear that. Do you want to talk about it, or would you prefer a distraction?",
            "That's tough. Make sure you're taking care of yourself today. Can I do anything to help?",
            "Aw, I hear you. Sometimes things can be a bit overwhelming. Want to hear a joke to cheer you up?",
        ],
    ],
    # Jokes
    [
        r"tell me a joke|make me laugh|got any jokes\?",
        [
            "Why don't skeletons fight each other? They just don't have the guts! Ba-dum-tss.",
            "I would tell you a joke about UDP, but you might not get it.",
            "Why did the scarecrow win an award? Because he was outstanding in his field!",
            "What do you call fake spaghetti? An impasta!",
        ],
    ],
    # Gratitude
    [
        r"thank you|thanks|thx|appreciate it",
        [
            "Anytime! Glad I could help.",
            "You got it! Let me know if you need anything else.",
            "No problem at all! Happy to help.",
        ],
    ],
    # Asking for help
    [
        r"(.*) (help|assist|support) (.*)",
        [
            "I've got your back. What specifically do you need help with regarding %3?",
            "Sure thing! Let's figure out %3 together. What's the main issue?",
        ],
    ],
    # Weather / Time (casual filler)
    [
        r"what time is it\?|what's the time\?",
        [
            "Time flies when you're chatting with me! You might want to check the clock on your device though, since I don't track local time zones.",
        ],
    ],
    # Goodbyes
    [
        r"bye|exit|goodbye|see ya|catch you later",
        [
            "Goodbye! Have an awesome day ahead!",
            "See you later! Feel free to drop by whenever you need anything.",
            "Take care! Catch you next time.",
        ],
    ],
    # Fallback / Catch-all (crucial for keeping it human-like)
    [
        r"(.*)",
        [
            "Hmm, I'm not entirely sure I follow. Could you say that a bit differently?",
            "My bad, I missed that. What do you mean?",
            "That's a new one for me! Could you elaborate a little more?",
            "I'm drawing a blank on that one. Want to try explaining it another way?",
        ],
    ],
]

# %%
class RuleBasedChatbot:
    def __init__(self, pairs):
        self.chat = Chat(pairs, reflections)

    def respond(self, user_input):
        return self.chat.respond(user_input)

# %%
def chat_with_bot():
    print("Hello, I am your chatbot! Type 'exit' to end the conversation.")
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            print("Chatbot: Goodbye! Have a nice day!")
            break
        response = chatbot.respond(user_input)
        print(f"Chatbot: {response}")

# %%
chatbot = RuleBasedChatbot(pairs)
chat_with_bot()
# Out:
# Hello, I am your chatbot! Type 'exit' to end the conversation.
# You:  Hi
# Chatbot: Hey! Good to see you. What can I do for you?
# You:  How are you?
# Chatbot: All systems are running smoothly! How's your day going?
# You:  what is you name ?
# Chatbot: Hmm, I'm not entirely sure I follow. Could you say that a bit differently?
# You:  tell me a jock
# Chatbot: That's a new one for me! Could you elaborate a little more?
# You:  tell me a joke
# Chatbot: What do you call fake spaghetti? An impasta!
# You:  tell me a joke
# Chatbot: I would tell you a joke about UDP, but you might not get it.
# You:  tell me a joke|make me laugh|got any jokes\?
# Chatbot: Why did the scarecrow win an award? Because he was outstanding in his field!
# You:  thank you
# Chatbot: You got it! Let me know if you need anything else.
# You:  bye
# Chatbot: See you later! Feel free to drop by whenever you need anything.
# You:  exit
# Chatbot: Goodbye! Have a nice day!
